# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data=pd.read_csv('/content/drive/MyDrive/Dataset/HousePrice.csv')
data
# Out:
#    House_id       Area  Bedrooms  Bathrooms  Square_feet    Price
# 0       102     Halord         2          1         1200  1500000
# 1       103   Stanford         3          2         1500  1800000
# 2       104  Robbinord         1          1         1000  1200000
# 3       105      Stela         2          2         1250  1300000
# 4       106     Derord         3          1          900  1000000
# 5       107    Semford         1          2          800   900000
# 6       108     Deccan         2          1         1450   140000
# 7       109    Helform         3          2         1800  2000000
# 8       110   Felimord         1          1          700   700000

# %%
features=data[["Bedrooms","Bathrooms","Square_feet"]]

# %%
target=data["Price"]

# %%
features=features.dropna()

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
x_test["pred"]=y_pred

# %%
x_test
# Out:
#    Bedrooms  Bathrooms  Square_feet          pred
# 7         3          2         1800  1.018998e+06
# 1         3          2         1500  1.113194e+06

# %%
x_test["pred"]=x_test["pred"].round()

# %%
x_test
# Out:
#    Bedrooms  Bathrooms  Square_feet       pred
# 7         3          2         1800  1018998.0
# 1         3          2         1500  1113194.0

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
print("the mean_squared error is:",mse.round())
# Out:
# the mean_squared error is: 717033682733.0

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='black', linestyle='-.')
plt.show()
